# %%
# %run dataset.ipynb
# Out:
# [INFO] DataManager: Dataset already exists, skipping fetch

# %%
data_folder = os.path.join("..", "res", "datasets")

# %%
dman = DataManager("mymail@example.com", data_folder)

# %%
dman

# %%
dataset_name = "RNA Dataset"
queries = ["RNA", "mRNA", "tRNA"]

# %%
dman.create_dataset(queries, dataset_name, 5)
# Out:
# [INFO] DataManager: Dataset already exists, skipping fetch

# %%
abstracts = dman.load_full_dataset(dataset_name)

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
# Out:
# [DEBUG] tensorflow: Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.

# %%
tokenizer = Tokenizer()

# %%
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, LSTM, Embedding

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
abstracts[0]
# Out:
# 'Long noncoding RNA nuclear paraspeckle assembly transcript 1 (lncRNA NEAT1) is abnormally expressed in numerous tumors and functions as an oncogene, but the role of NEAT1 in laryngocarcinoma is largely unknown. Our study validated that NEAT1 expression was markedly upregulated in laryngocarcinoma tissues and cells. Downregulation of NEAT1 dramatically suppressed cell proliferation and invasion through inhibiting miR-524-5p expression. Additionally, NEAT1 overexpression promoted cell growth and metastasis, while overexpression of miR-524-5p could reverse the effect. NEAT1 increased the expression of histone deacetylase 1 gene (HDAC1) via sponging miR-524-5p. Mechanistically, overexpression of HDAC1 recovered the cancer-inhibiting effects of miR-524-5p mimic or NEAT1 silence by deacetylation of tensin homolog deleted on chromosome ten (PTEN) and inhibiting AKT signal pathway. Moreover, in vivo experiments indicated that silence of NEAT1 signally suppressed tumor growth. Taken together, knockdown of NEAT1 suppressed laryngocarcinoma cell growth and metastasis by miR-524-5p/HDAC1/PTEN/AKT signal pathway, which provided a potential therapeutic target for laryngocarcinoma.'

# %%
type(abstracts[0])
# Out:
# str

# %%
def clean_text(doc):
    tokens = doc.split()
    table =str.maketrans('','', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    tokens = [word.lower() for word in tokens]
    return tokens

# %%
tokens = clean_text(abstracts[0])

# %%
len(tokens)
# Out:
# 134

# %%
len(set(tokens))
# Out:
# 94

# %%
length = 30+1
lines = []
for i in range(length, len(tokens)):
    seq = tokens[i-length:i]
    line = ' '.join(seq)
    lines.append(line)

# %%
lines = []

# %%
length = 50+1

# %%
for abstract in abstracts:
    tokens = clean_text(abstract)
    for i in range(length, len(tokens)):
        seq = tokens[i-length:i]
        line = ' '.join(seq)
        lines.append(line)

# %%
len(lines)
# Out:
# 2262

# %%
###Build LSTM Model and Prepare x and y

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %%
sequences = np.array(sequences)

# %%
X, y = sequences[:, :-1], sequences[:, -1]

# %%
X[0]
# Out:
# array([1039,  289,   30,  746, 1018, 1009,  998,  988,   17,  969,  350,
#           4,  949,  850,    2,  919,   19,   34,  893,  186,    1,  116,
#           3,    4,  314,   17,  341,  336,   64,   23,  199,   15,    7,
#           6,  797,  197,    4,  314,   74,    2,   14,  747,    3,  733,
#         174,   25,   39,    2,   89,   53])

# %%
y[0]
# Out:
# 204

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'of': 3,
#  'in': 4,
#  'to': 5,
#  'was': 6,
#  'expression': 7,
#  'were': 8,
#  'with': 9,
#  'a': 10,
#  'by': 11,
#  'for': 12,
#  'protein': 13,
#  'cells': 14,
#  'that': 15,
#  'this': 16,
#  'is': 17,
#  'p': 18,
#  'as': 19,
#  'we': 20,
#  'from': 21,
#  'levels': 22,
#  'study': 23,
#  'results': 24,
#  'cell': 25,
#  'nscs': 26,
#  'using': 27,
#  'showed': 28,
#  'gene': 29,
#  'rna': 30,
#  'increased': 31,
#  'genes': 32,
#  'analysis': 33,
#  'an': 34,
#  'transcription': 35,
#  'significantly': 36,
#  'on': 37,
#  'different': 38,
#  'proliferation': 39,
#  'or': 40,
#  'most': 41,
#  'which': 42,
#  'sourdough': 43,
#  'viability': 44,
#  'b': 45,
#  'identified': 46,
#  'mrna': 47,
#  'after': 48,
#  'potential': 49,
#  'compared': 50,
#  'decidualization': 51,
#  'dlnbp': 52,
#  'through': 53,
#  'related': 54,
#  'evaluated': 55,
#  'stable': 56,
#  'ribosomal': 57,
#  'treated': 58,
#  'trfs': 59,
#  'signal': 60,
#  'crayfish': 61,
#  'decreased': 62,
#  'viruses': 63,
#  'our': 64,
#  'function': 65,
#  'can': 66,
#  'their': 67,
#  'hypoxic': 68,
#  'reverse': 69,
#  'mm': 70,
#  'these': 71,
#  'methods': 72,
#  'also': 73,
#  'tissues': 74,
#  'brain': 75,
#  'clpfesa': 76,
#  'between': 77,
#  'tissue': 78,
#  'ich': 79,
#  'cereus': 80,
#  'target': 81,
#  'assay': 82,
#  'database': 83,
#  'polymerase': 84,
#  'quantitative': 85,
#  'including': 86,
#  'factor': 87,
#  'abundance': 88,
#  'invasion': 89,
#  'striatal': 90,
#  'overexpression': 91,
#  'patients': 92,
#  'resistance': 93,
#  'tmao': 94,
#  'pathway': 95,
#  'crucial': 96,
#  'may': 97,
#  'btz': 98,
#  'mechanisms': 99,
#  'cancer': 100,
#  'observed': 101,
#  'markers': 102,
#  'concentrations': 103,
#  'be': 104,
#  'into': 105,
#  'trnaaspgtc': 106,
#  'stress': 107,
#  'studies': 108,
#  'positive': 109,
#  'glucosamine': 110,
#  'further': 111,
#  'its': 112,
#  'reference': 113,
#  'normal': 114,
#  'crc': 115,
#  'role': 116,
#  'under': 117,
#  'gbm': 118,
#  'culture': 119,
#  'lipid': 120,
#  'villosa': 121,
#  'diagnostic': 122,
#  'conclusion': 123,
#  'has': 124,
#  'species': 125,
#  'could': 126,
#  'data': 127,
#  'saltstressed': 128,
#  'stems': 129,
#  'coldstressed': 130,
#  'interaction': 131,
#  'mum': 132,
#  'model': 133,
#  'assessed': 134,
#  'western': 135,
#  'blotting': 136,
#  'determine': 137,
#  'both': 138,
#  'days': 139,
#  'level': 140,
#  'mouse': 141,
#  'controls': 142,
#  'dems': 143,
#  'regulation': 144,
#  'chain': 145,
#  'reaction': 146,
#  'rtqpcr': 147,
#  'measured': 148,
#  'mixedculturebased': 149,
#  'isolates': 150,
#  'important': 151,
#  'along': 152,
#  'changes': 153,
#  'detect': 154,
#  'however': 155,
#  'promoted': 156,
#  'have': 157,
#  'pmlkl': 158,
#  'pjnk': 159,
#  'zone': 160,
#  'increase': 161,
#  'activation': 162,
#  'single': 163,
#  'detected': 164,
#  'mexican': 165,
#  'vegf': 166,
#  'pten': 167,
#  'phylogenetically': 168,
#  'inflammation': 169,
#  'treatment': 170,
#  'differentiation': 171,
#  'not': 172,
#  'growth': 173,
#  'suppressed': 174,
#  'well': 175,
#  'tumor': 176,
#  'at': 177,
#  'targets': 178,
#  'vivo': 179,
#  'powder': 180,
#  'new': 181,
#  'downregulated': 182,
#  'damage': 183,
#  'trnavalaaccac': 184,
#  'chili': 185,
#  'but': 186,
#  'pregnancy': 187,
#  'materials': 188,
#  'used': 189,
#  'it': 190,
#  'samples': 191,
#  'mechanism': 192,
#  'dehydrogenase': 193,
#  'myeloma': 194,
#  'stage': 195,
#  'diet': 196,
#  'upregulated': 197,
#  'drought': 198,
#  'validated': 199,
#  'effects': 200,
#  'mice': 201,
#  'associated': 202,
#  'mirnas': 203,
#  'inhibiting': 204,
#  'group': 205,
#  'osmr': 206,
#  'cerebral': 207,
#  'kinase': 208,
#  'underlying': 209,
#  'drug': 210,
#  'models': 211,
#  'production': 212,
#  'clinical': 213,
#  'remain': 214,
#  'cancers': 215,
#  'exosomal': 216,
#  'human': 217,
#  'been': 218,
#  'additionally': 219,
#  'histone': 220,
#  'stability': 221,
#  'three': 222,
#  'leaves': 223,
#  'roots': 224,
#  'tested': 225,
#  'targeting': 226,
#  'assays': 227,
#  'besides': 228,
#  'iv': 229,
#  'then': 230,
#  'performed': 231,
#  'investigate': 232,
#  'sites': 233,
#  'transfected': 234,
#  'method': 235,
#  'roc': 236,
#  'curve': 237,
#  'sequencing': 238,
#  'respectively': 239,
#  'all': 240,
#  'pathways': 241,
#  'negative': 242,
#  'wb': 243,
#  'realtime': 244,
#  'proinflammatory': 245,
#  'evaluate': 246,
#  'experimental': 247,
#  'hours': 248,
#  'mtt': 249,
#  'apoptosis': 250,
#  'ischemiainduced': 251,
#  'pcr': 252,
#  'derived': 253,
#  'biochemical': 254,
#  'microgml': 255,
#  'hbl': 256,
#  'component': 257,
#  'range': 258,
#  'metastasis': 259,
#  'candidate': 260,
#  'enhancing': 261,
#  'metabolism': 262,
#  'values': 263,
#  'signaling': 264,
#  'macrophages': 265,
#  'factors': 266,
#  'indicate': 267,
#  'approach': 268,
#  'selected': 269,
#  'datasets': 270,
#  'composition': 271,
#  'viral': 272,
#  'mirna': 273,
#  'subventricular': 274,
#  'stromal': 275,
#  'differences': 276,
#  'cellular': 277,
#  'sl': 278,
#  'recovered': 279,
#  'future': 280,
#  'synthetase': 281,
#  'acid': 282,
#  'fragments': 283,
#  'accumulation': 284,
#  'regulate': 285,
#  'number': 286,
#  'trnaderived': 287,
#  'toxigenic': 288,
#  'noncoding': 289,
#  'possible': 290,
#  'necroptosis': 291,
#  'disease': 292,
#  'organism': 293,
#  'edema': 294,
#  'present': 295,
#  'condition': 296,
#  'characteristics': 297,
#  'neurobehavioral': 298,
#  'involved': 299,
#  'environment': 300,
#  'biomarker': 301,
#  'components': 302,
#  'sought': 303,
#  'while': 304,
#  'determined': 305,
#  'receptors': 306,
#  'during': 307,
#  'among': 308,
#  'thus': 309,
#  'virome': 310,
#  'macrophage': 311,
#  'high': 312,
#  'previously': 313,
#  'laryngocarcinoma': 314,
#  'prognostic': 315,
#  'structure': 316,
#  'elucidate': 317,
#  'response': 318,
#  'activity': 319,
#  'influence': 320,
#  'divergent': 321,
#  'silence': 322,
#  'various': 323,
#  'responsiveness': 324,
#  'regard': 325,
#  'pyruvate': 326,
#  'indicated': 327,
#  'region': 328,
#  'profiles': 329,
#  'metastatic': 330,
#  'some': 331,
#  'aim': 332,
#  'serum': 333,
#  'early': 334,
#  'recently': 335,
#  'unknown': 336,
#  'facilitate': 337,
#  'downregulating': 338,
#  'prognosis': 339,
#  'conditions': 340,
#  'largely': 341,
#  'knockdown': 342,
#  'process': 343,
#  'key': 344,
#  'stem': 345,
#  'abiotic': 346,
#  'neural': 347,
#  'four': 348,
#  'ischemic': 349,
#  'expressed': 350,
#  'transfer': 351,
#  'because': 352,
#  'cause': 353,
#  'metabolic': 354,
#  'bacillus': 355,
#  'association': 356,
#  'effect': 357,
#  'novel': 358,
#  'er': 359,
#  'plantarum': 360,
#  'cerevisiae': 361,
#  'animal': 362,
#  'bacteria': 363,
#  'inhibition': 364,
#  'induces': 365,
#  'food': 366,
#  'sporeforming': 367,
#  'inflammatory': 368,
#  'reactions': 369,
#  'research': 370,
#  'result': 371,
#  'taken': 372,
#  'bioactive': 373,
#  'are': 374,
#  'deacetylase': 375,
#  'via': 376,
#  'sponging': 377,
#  'mechanistically': 378,
#  'cancerinhibiting': 379,
#  'together': 380,
#  'nine': 381,
#  'based': 382,
#  'prior': 383,
#  'transcriptomic': 384,
#  'treatments': 385,
#  'simulating': 386,
#  'bioinformatics': 387,
#  'assessments': 388,
#  'family': 389,
#  'elongation': 390,
#  'act': 391,
#  'actin': 392,
#  'droughtstressed': 393,
#  'tua': 394,
#  'alphatubulin': 395,
#  'rrna': 396,
#  'utility': 397,
#  'mirnagene': 398,
#  'mode': 399,
#  'acylcoa': 400,
#  'oxidase': 401,
#  'lowest': 402,
#  'effective': 403,
#  'loecs': 404,
#  'silico': 405,
#  'molecule': 406,
#  'fluorescentbased': 407,
#  'electrophoretic': 408,
#  'mobility': 409,
#  'shift': 410,
#  'fremsa': 411,
#  'luciferase': 412,
#  'reporter': 413,
#  'directly': 414,
#  'bind': 415,
#  'inhibit': 416,
#  'clarify': 417,
#  'monocyte': 418,
#  'chemoattractant': 419,
#  'identify': 420,
#  'established': 421,
#  'injecting': 422,
#  'collagenase': 423,
#  'right': 424,
#  'basal': 425,
#  'ganglia': 426,
#  'inhibitor': 427,
#  'administered': 428,
#  'intraventricular': 429,
#  'injection': 430,
#  'employed': 431,
#  'phosphomixed': 432,
#  'lineage': 433,
#  'domainlike': 434,
#  'phosphocjun': 435,
#  'nterminal': 436,
#  'interleukin': 437,
#  'localization': 438,
#  'immunofluorescence': 439,
#  'staining': 440,
#  'coimmunoprecipitation': 441,
#  'sham': 442,
#  'found': 443,
#  'examination': 444,
#  'strongly': 445,
#  'implantation': 446,
#  'interimplantation': 447,
#  'location': 448,
#  'distributed': 449,
#  'decidual': 450,
#  'upon': 451,
#  'exploration': 452,
#  'artificially': 453,
#  'induced': 454,
#  'vitro': 455,
#  'interfering': 456,
#  'primary': 457,
#  'endometrial': 458,
#  'expressions': 459,
#  'uterus': 460,
#  'impaired': 461,
#  'led': 462,
#  'loss': 463,
#  'implanted': 464,
#  'embryos': 465,
#  'downloaded': 466,
#  'omnibus': 467,
#  'differentially': 468,
#  'limma': 469,
#  'receiver': 470,
#  'operating': 471,
#  'characteristic': 472,
#  'predicted': 473,
#  'mirwalk': 474,
#  'enrichment': 475,
#  'david': 476,
#  'tcga': 477,
#  'immunohistochemistry': 478,
#  'seven': 479,
#  'shared': 480,
#  'two': 481,
#  'constituted': 482,
#  'signature': 483,
#  'distinguish': 484,
#  'area': 485,
#  'nearly': 486,
#  'approximate': 487,
#  'ii': 488,
#  'promoter': 489,
#  'division': 490,
#  'dnatemplated': 491,
#  'cellcounting': 492,
#  'evaluating': 493,
#  'vascular': 494,
#  'endothelial': 495,
#  'quantified': 496,
#  'enzymelinked': 497,
#  'immunosorbent': 498,
#  'gl': 499,
#  'optimal': 500,
#  'concentration': 501,
#  'improve': 502,
#  'astrocytes': 503,
#  'oligodendrocytes': 504,
#  'meanwhile': 505,
#  'elevate': 506,
#  'transfection': 507,
#  'sirna': 508,
#  'stimulates': 509,
#  'cytokines': 510,
#  'designed': 511,
#  'tmaotreated': 512,
#  'exposed': 513,
#  'murine': 514,
#  'line': 515,
#  'butyric': 516,
#  'tunicamycin': 517,
#  'inducing': 518,
#  'erstress': 519,
#  'test': 520,
#  'oneway': 521,
#  'anova': 522,
#  'statistical': 523,
#  'no': 524,
#  'death': 525,
#  'doses': 526,
#  'significant': 527,
#  'elevation': 528,
#  'andor': 529,
#  'when': 530,
#  'completely': 531,
#  'aims': 532,
#  'antagomir': 533,
#  'if': 534,
#  'analysed': 535,
#  'colorimetric': 536,
#  'bromide': 537,
#  'annexin': 538,
#  'vpropidium': 539,
#  'iodide': 540,
#  'pi': 541,
#  'flow': 542,
#  'cytometry': 543,
#  'qrtpcr': 544,
#  'implemented': 545,
#  'bcell': 546,
#  'lymphoma': 547,
#  'antiapoptotic': 548,
#  'cycle': 549,
#  'exacerbated': 550,
#  'rate': 551,
#  'inadequacy': 552,
#  'existing': 553,
#  'developed': 554,
#  'mimicking': 555,
#  'internal': 556,
#  'artery': 557,
#  'occlusion': 558,
#  'mild': 559,
#  'moderate': 560,
#  'ameliorated': 561,
#  'behavioral': 562,
#  'dysfunction': 563,
#  'rescued': 564,
#  'upregulation': 565,
#  'ex': 566,
#  'neurosphere': 567,
#  'involving': 568,
#  'cellsneural': 569,
#  'progenitor': 570,
#  'large': 571,
#  'neurospheres': 572,
#  'nestin': 573,
#  'lastly': 574,
#  'coronal': 575,
#  'sixty': 576,
#  'postoperative': 577,
#  'consisting': 578,
#  'adjacent': 579,
#  'collected': 580,
#  'mintbase': 581,
#  'select': 582,
#  'taqman': 583,
#  'technology': 584,
#  'correlation': 585,
#  'clinicopathological': 586,
#  'lower': 587,
#  'comparison': 588,
#  'iii': 589,
#  'trnavalaac': 590,
#  'basic': 591,
#  'nutriments': 592,
#  'living': 593,
#  'development': 594,
#  'influencing': 595,
#  'healthdisease': 596,
#  'chromatin': 597,
#  'dna': 598,
#  'methylation': 599,
#  'modification': 600,
#  'fermented': 601,
#  'either': 602,
#  'mixed': 603,
#  'proteomics': 604,
#  'show': 605,
#  'carbohydrate': 606,
#  'greater': 607,
#  'llactate': 608,
#  'udpglucose': 609,
#  'contribute': 610,
#  'quality': 611,
#  'than': 612,
#  'those': 613,
#  'produced': 614,
#  'calreticulin': 615,
#  'enolase': 616,
#  'seryltrna': 617,
#  'needed': 618,
#  'proteins': 619,
#  'compounds': 620,
#  'play': 621,
#  'members': 622,
#  'colonies': 623,
#  'grew': 624,
#  'agar': 625,
#  'medium': 626,
#  'selective': 627,
#  'sensu': 628,
#  'lato': 629,
#  'supplemented': 630,
#  'polymyxin': 631,
#  'ampicillin': 632,
#  'presumptive': 633,
#  'trnacyspcrbased': 634,
#  'thuringiensis': 635,
#  'toyonensis': 636,
#  'serological': 637,
#  'tests': 638,
#  'enterotoxins': 639,
#  'nhe': 640,
#  'hemolysin': 641,
#  'bl': 642,
#  'c': 643,
#  'hblc': 644,
#  'nonhemolytic': 645,
#  'enterotoxin': 646,
#  'nhea': 647,
#  'antibiotic': 648,
#  'betalactams': 649,
#  'trimethoprimsulfamethoxazole': 650,
#  'tetracycline': 651,
#  'erythromycin': 652,
#  'clindamycin': 653,
#  'chloramphenicol': 654,
#  'korana': 655,
#  'river': 656,
#  'croatia': 657,
#  'highthroughput': 658,
#  'depleted': 659,
#  'total': 660,
#  'isolated': 661,
#  'hepatopancreas': 662,
#  'subsequent': 663,
#  'sequence': 664,
#  'crayfishassociated': 665,
#  'reolike': 666,
#  'hepelike': 667,
#  'totilike': 668,
#  'picornalike': 669,
#  'crustacean': 670,
#  'hosts': 671,
#  'patterns': 672,
#  'reads': 673,
#  'calculated': 674,
#  'nucleotide': 675,
#  'diversities': 676,
#  'sequences': 677,
#  'varied': 678,
#  'processes': 679,
#  'eg': 680,
#  'population': 681,
#  'density': 682,
#  'nonrandom': 683,
#  'dispersal': 684,
#  'host': 685,
#  'individuals': 686,
#  'core': 687,
#  'mimic': 688,
#  'specifically': 689,
#  'disorders': 690,
#  'pathogenesis': 691,
#  'due': 692,
#  'sections': 693,
#  'energy': 694,
#  'possibly': 695,
#  'containing': 696,
#  'presence': 697,
#  'isolation': 698,
#  'pparalphaindependent': 699,
#  'postich': 700,
#  'objective': 701,
#  'hypoxiainducible': 702,
#  'direct': 703,
#  'considerably': 704,
#  'general': 705,
#  'source': 706,
#  'nutritional': 707,
#  'fronts': 708,
#  'manner': 709,
#  'clpfesainduced': 710,
#  'pretreatment': 711,
#  'sirnamediated': 712,
#  'tlrs': 713,
#  'control': 714,
#  'detection': 715,
#  'deacetylation': 716,
#  'investigated': 717,
#  'outcomes': 718,
#  'unsatisfactory': 719,
#  'signalling': 720,
#  'within': 721,
#  'unfavorable': 722,
#  'reduced': 723,
#  'profile': 724,
#  'impact': 725,
#  'tolllike': 726,
#  'tunicamycintreated': 727,
#  'remained': 728,
#  'only': 729,
#  'cascades': 730,
#  'flavour': 731,
#  'invasive': 732,
#  'dramatically': 733,
#  'tensin': 734,
#  'therapeutic': 735,
#  'utilization': 736,
#  'globe': 737,
#  'homolog': 738,
#  'pattern': 739,
#  'will': 740,
#  'reported': 741,
#  'injuries': 742,
#  'cultured': 743,
#  'stroke': 744,
#  'saccharomyces': 745,
#  'nuclear': 746,
#  'downregulation': 747,
#  'deleted': 748,
#  'neurological': 749,
#  'betaoxidation': 750,
#  'atherosclerosis': 751,
#  'triggers': 752,
#  'ligand': 753,
#  'citrate': 754,
#  'around': 755,
#  'housekeeping': 756,
#  'essential': 757,
#  'binding': 758,
#  'synthase': 759,
#  'diets': 760,
#  'chromosome': 761,
#  'contributing': 762,
#  'accompanied': 763,
#  'fatty': 764,
#  'many': 765,
#  'distant': 766,
#  'fermentation': 767,
#  'lactiplantibacillus': 768,
#  'aldehyde': 769,
#  'l': 770,
#  'native': 771,
#  'ten': 772,
#  'better': 773,
#  'like': 774,
#  'cooccurring': 775,
#  'mitigated': 776,
#  'reticulum': 777,
#  'part': 778,
#  'brdu': 779,
#  'rnas': 780,
#  'suite': 781,
#  'droughtrelated': 782,
#  'revealed': 783,
#  'toxicity': 784,
#  'steps': 785,
#  'explored': 786,
#  'endoplasmic': 787,
#  'oncogenic': 788,
#  'more': 789,
#  'decarboxylase': 790,
#  'leniusculus': 791,
#  'combined': 792,
#  'candidates': 793,
#  'small': 794,
#  'whole': 795,
#  'pacifastacus': 796,
#  'markedly': 797,
#  'akt': 798,
#  'establish': 799,
#  'catalyzing': 800,
#  'progress': 801,
#  'plays': 802,
#  'decrease': 803,
#  'enzyme': 804,
#  'interest': 805,
#  'rats': 806,
#  'problem': 807,
#  'dcx': 808,
#  'demonstrated': 809,
#  'interactions': 810,
#  'spice': 811,
#  'animals': 812,
#  'preventing': 813,
#  'defects': 814,
#  'fetal': 815,
#  'major': 816,
#  'translation': 817,
#  'acetylcoa': 818,
#  'moreover': 819,
#  'provided': 820,
#  'worth': 821,
#  'low': 822,
#  'psammochloa': 823,
#  'first': 824,
#  'colocalized': 825,
#  'palmitoyltransferase': 826,
#  'noting': 827,
#  'obtained': 828,
#  'reveals': 829,
#  'report': 830,
#  'support': 831,
#  'carnitine': 832,
#  'given': 833,
#  'marker': 834,
#  'experiments': 835,
#  'hepatotoxicity': 836,
#  'exposure': 837,
#  'unclear': 838,
#  'remains': 839,
#  'summary': 840,
#  'selecting': 841,
#  'relevant': 842,
#  'perinuclear': 843,
#  'screen': 844,
#  'hippocampal': 845,
#  'newly': 846,
#  'genome': 847,
#  'organisms': 848,
#  'analyze': 849,
#  'tumors': 850,
#  'groups': 851,
#  'risk': 852,
#  'differentiating': 853,
#  'undiscovered': 854,
#  'validating': 855,
#  'aimed': 856,
#  'about': 857,
#  'diversity': 858,
#  'few': 859,
#  'might': 860,
#  'view': 861,
#  'induce': 862,
#  'ischemia': 863,
#  'immature': 864,
#  'known': 865,
#  'signally': 866,
#  'upregulate': 867,
#  'miscarriage': 868,
#  'neurons': 869,
#  'insights': 870,
#  'commercial': 871,
#  'decidua': 872,
#  'little': 873,
#  'infertility': 874,
#  'rarely': 875,
#  'weaker': 876,
#  'induction': 877,
#  'injury': 878,
#  'glucosaminetreated': 879,
#  'salt': 880,
#  'formation': 881,
#  'external': 882,
#  'modern': 883,
#  'dough': 884,
#  'wildlife': 885,
#  'linked': 886,
#  'hypoxia': 887,
#  'exact': 888,
#  'help': 889,
#  'raw': 890,
#  'annuum': 891,
#  'understudied': 892,
#  'oncogene': 893,
#  'cold': 894,
#  'environmental': 895,
#  'hemorrhage': 896,
#  'against': 897,
#  'cumulatively': 898,
#  'capsicum': 899,
#  'toxins': 900,
#  'intracerebral': 901,
#  'complex': 902,
#  'spontaneous': 903,
#  'biomarkers': 904,
#  'gbmrelated': 905,
#  'power': 906,
#  'similar': 907,
#  'bortezomib': 908,
#  'aggressive': 909,
#  'information': 910,
#  'aberrant': 911,
#  'abortion': 912,
#  'glioblastoma': 913,
#  'although': 914,
#  'lines': 915,
#  'diseases': 916,
#  'fungal': 917,
#  'elaborated': 918,
#  'functions': 919,
#  'disturbed': 920,
#  'what': 921,
#  'multiple': 922,
#  'marrow': 923,
#  'neuroprotective': 924,
#  'antineuroinflammatory': 925,
#  'proneurogenic': 926,
#  'confirming': 927,
#  'heterogeneous': 928,
#  'behavior': 929,
#  's': 930,
#  'pathogens': 931,
#  'sets': 932,
#  'sulfonate': 933,
#  'frequently': 934,
#  'pathological': 935,
#  'findings': 936,
#  'happens': 937,
#  'bone': 938,
#  'highly': 939,
#  'bacterial': 940,
#  'antibiotics': 941,
#  'foundations': 942,
#  'benefit': 943,
#  'homeostasis': 944,
#  'suggest': 945,
#  'leads': 946,
#  'constituents': 947,
#  'understand': 948,
#  'numerous': 949,
#  'conclusions': 950,
#  'step': 951,
#  'recommend': 952,
#  'understanding': 953,
#  'considerable': 954,
#  'investigations': 955,
#  'pfos': 956,
#  'there': 957,
#  'sugar': 958,
#  'malignant': 959,
#  'relations': 960,
#  'exerted': 961,
#  'plasma': 962,
#  'amino': 963,
#  'diagnosed': 964,
#  'finding': 965,
#  'consist': 966,
#  'activities': 967,
#  'successful': 968,
#  'abnormally': 969,
#  'china': 970,
#  'perfluorooctane': 971,
#  'following': 972,
#  'collectively': 973,
#  'considered': 974,
#  'provides': 975,
#  'neoplastic': 976,
#  'occurring': 977,
#  'commonly': 978,
#  'promising': 979,
#  'nutrigenomics': 980,
#  'serve': 981,
#  'microbiological': 982,
#  'northwest': 983,
#  'genomic': 984,
#  'documentation': 985,
#  'naturally': 986,
#  'allow': 987,
#  'lncrna': 988,
#  'product': 989,
#  'represent': 990,
#  'enhance': 991,
#  'nutrigenetics': 992,
#  'designing': 993,
#  'formed': 994,
#  'assessment': 995,
#  'ecosystems': 996,
#  'virus': 997,
#  'transcript': 998,
#  'growing': 999,
#  'alternative': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 1048

# %%
y = to_categorical(y, num_classes=vocab_size)

# %%
seq_length = X.shape[1]

# %%
###LSTM Model

# %%
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            52400
#
#  lstm (LSTM)                 (None, 50, 100)           60400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 1048)              105848
#
# =================================================================
# Total params: 309,148
# Trainable params: 309,148
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(X, y, batch_size =256, epochs =30)
# Out:
# Epoch 1/30
# 9/9 [==============================] - 6s 208ms/step - loss: 6.9436 - accuracy: 0.0429
# Epoch 2/30
# 9/9 [==============================] - 2s 193ms/step - loss: 6.5846 - accuracy: 0.0318
# Epoch 3/30
# 9/9 [==============================] - 2s 198ms/step - loss: 6.0632 - accuracy: 0.0407
# Epoch 4/30
# 9/9 [==============================] - 2s 207ms/step - loss: 5.9265 - accuracy: 0.0486
# Epoch 5/30
# 9/9 [==============================] - 2s 212ms/step - loss: 5.8819 - accuracy: 0.0535
# Epoch 6/30
# 9/9 [==============================] - 3s 286ms/step - loss: 5.8666 - accuracy: 0.0531
# Epoch 7/30
# 9/9 [==============================] - 2s 251ms/step - loss: 5.8569 - accuracy: 0.0553
# Epoch 8/30
# 9/9 [==============================] - 2s 259ms/step - loss: 5.8539 - accuracy: 0.0579
# Epoch 9/30
# 9/9 [==============================] - 2s 219ms/step - loss: 5.8531 - accuracy: 0.0579
# Epoch 10/30
# 9/9 [==============================] - 2s 237ms/step - loss: 5.8516 - accuracy: 0.0579
# Epoch 11/30
# 9/9 [==============================] - 2s 264ms/step - loss: 5.8501 - accuracy: 0.0579
# Epoch 12/30
# 9/9 [==============================] - 2s 237ms/step - loss: 5.8498 - accuracy: 0.0579
# Epoch 13/30
# 9/9 [==============================] - 2s 232ms/step - loss: 5.8532 - accuracy: 0.0579
# Epoch 14/30
# 9/9 [==============================] - 3s 281ms/step - loss: 5.8502 - accuracy: 0.0544
# Epoch 15/30
# 9/9 [==============================] - 2s 259ms/step - loss: 5.8473 - accuracy: 0.0579
# Epoch 16/30
# 9/9 [==============================] - 3s 277ms/step - loss: 5.8458 - accuracy: 0.0579
# Epoch 17/30
# 9/9 [==============================] - 3s 288ms/step - loss: 5.8464 - accuracy: 0.0495
# Epoch 18/30
# 9/9 [==============================] - 3s 280ms/step - loss: 5.8440 - accuracy: 0.0579
# Epoch 19/30
# 9/9 [==============================] - 2s 270ms/step - loss: 5.8404 - accuracy: 0.0579
# Epoch 20/30
# 9/9 [==============================] - 2s 267ms/step - loss: 5.8376 - accuracy: 0.0513
# Epoch 21/30
# 9/9 [==============================] - 2s 253ms/step - loss: 5.8316 - accuracy: 0.0579
# Epoch 22/30
# 9/9 [==============================] - 3s 290ms/step - loss: 5.8169 - accuracy: 0.0597
# Epoch 23/30
# 9/9 [==============================] - 3s 290ms/step - loss: 5.7936 - accuracy: 0.0579
# Epoch 24/30
# 9/9 [==============================] - 3s 306ms/step - loss: 5.7529 - accuracy: 0.0672
# Epoch 25/30
# 9/9 [==============================] - 3s 303ms/step - loss: 5.6957 - accuracy: 0.0721
# Epoch 26/30
# 9/9 [==============================] - 2s 263ms/step - loss: 5.6406 - accuracy: 0.0729
# Epoch 27/30
# 9/9 [==============================] - 2s 249ms/step - loss: 5.5901 - accuracy: 0.0729
# Epoch 28/30
# 9/9 [==============================] - 2s 279ms/step - loss: 5.5523 - accuracy: 0.0787
# Epoch 29/30
# 9/9 [==============================] - 2s 267ms/step - loss: 5.5243 - accuracy: 0.0747
# Epoch 30/30
# 9/9 [==============================] - 2s 232ms/step - loss: 5.4954 - accuracy: 0.0796
